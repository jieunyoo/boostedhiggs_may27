# %%
import argparse
import glob
import json
import logging
import os
import pickle as pkl
import warnings

import hist as hist2
import numpy as np
import pandas as pd
import pyarrow
import yaml
from systematics import get_systematic_dict, sigs
from utils import get_common_sample_name, get_finetuned_score, get_xsecweight

logging.basicConfig(level=logging.INFO)

warnings.filterwarnings("ignore", message="Found duplicate branch ")
pd.set_option("mode.chained_assignment", None)

sigs = ["ggF", "VBF", "WH", "ZH", "ttH"]
bkgs = ["TTbar", "WJetsLNu", "SingleTop", "WZQQ", "Diboson", "EWKvjets", "DYJets"]

#WFACTOR = 1
#2016: 1.129
#2016APV: 1.1
#2017: 1.043
#2018: 1.027

#this is hacky - but anyway just change this calibrated factor per year

#2018 
nom_trig = [  0.97316853, 1.00480192, 0.99773121, 1.00115747, 0.97460874,1.02083724, 1.00569659, 0.99931007, 0.97253711, 1.02816501, 0.9582612 , 0.99847442, 0.9663244 , 1.00026573, 0.97930598]
up_trig = [1.04406395, 1.0161899 , 1.00818656, 1.01453322, 1.0504374,1.05290024, 1.01810422, 1.0107254 , 0.98913642, 1.06335367,0.99717576, 1.0172449 , 0.98301419, 1.02056413, 1.01756531]
down_trig = [0.94615435, 1.00361001, 0.99175464, 0.99613031, 0.9455259, 1.00181298, 0.99597402, 0.98982106, 0.95861722, 1.00558644, 0.92292573, 0.98087248, 0.9504349 , 0.9812107 , 0.94474428]

#2017
nom_trig2017 = [1.01467505, 0.99558953, 0.99596328, 0.97266757, 1.01680672,0.91771569, 0.97330338, 0.9628086 , 0.94945886, 0.93074193,0.88346762, 0.93986709, 0.95049357, 0.96395947, 0.96216591 ]
up_trig2017 = [1.08202419, 1.01316206, 1.00933387, 0.99761035, 1.09885624, 0.98177762, 0.99283257, 0.97860141, 0.96964921, 0.99310961, 0.93970839, 0.96592046, 0.97095216, 0.98912634, 1.01346021]
down_trig2017 = [1.00919919, 0.9891299 , 0.98928763, 0.95716839, 1.01091358, 0.86905073, 0.95735603, 0.94920227, 0.93221049, 0.88617271,0.83084485, 0.91516138, 0.93099722, 0.94018822, 0.91551657 ]

#2016
nom_trig2016 = [1.00984252, 0.98759196, 0.99880955, 0.9905723 , 1.00215983,0.98220745, 1.01275276, 0.98584499, 1.00147192, 1.02677684,0.91866763, 1.00740741, 1.02089672, 1.04459947, 0.96555385 ]
up_trig2016 = [1.08470782, 1.01762475, 1.01440987, 1.01465713, 1.09484157,1.03099084, 1.02538254, 1.00007443, 1.01757504, 1.06379468,0.98139906, 1.03550959, 1.04627989, 1.07175043, 1.02924617 ]
down_trig2016 = [1.00555572, 0.97653751, 0.9930635 , 0.98174029, 1.00036919, 0.95711356, 1.00545487, 0.97463365, 0.99051333, 1.0122556,0.85933502, 0.98129079, 0.99705125, 1.01968035, 0.90658386 ]

def applyTriggerSF_2018(lep_pt,lep_eta):
    if lep_pt < 2000 and lep_pt > 200 and lep_eta < -1.5 and lep_eta > -2.5:
        return nom_trig[0]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < -0.5 and lep_eta > -1.5:
        return nom_trig[1]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 0.5 and lep_eta > -0.5:
        return nom_trig[2]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 1.5 and lep_eta > 0.5:
        return nom_trig[3]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 2.5 and lep_eta > 1.5:
        return nom_trig[4]
    if lep_pt < 200 and lep_pt > 120 and lep_eta < -1.5 and lep_eta > -2.5:
        return nom_trig[5]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < -0.5 and lep_eta > -1.5:
        return nom_trig[6]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 0.5 and lep_eta > -0.5:
        return nom_trig[7]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 1.5 and lep_eta > 0.5:
        return nom_trig[8]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return nom_trig[9]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -1.5 and lep_eta > -2.5:
        return nom_trig[10]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -0.5 and lep_eta > -1.5:
        return nom_trig[11]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 0.5 and lep_eta > -0.5:
        return nom_trig[12]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 1.5 and lep_eta > 0.5:
        return nom_trig[13]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return nom_trig[14]
    else:
        return 1

def applyTriggerSF_2017(lep_pt,lep_eta):
    if lep_pt < 2000 and lep_pt > 200 and lep_eta < -1.5 and lep_eta > -2.5:
        return nom_trig2017[0]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < -0.5 and lep_eta > -1.5:
        return nom_trig2017[1]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 0.5 and lep_eta > -0.5:
        return nom_trig2017[2]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 1.5 and lep_eta > 0.5:
        return nom_trig2017[3]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 2.5 and lep_eta > 1.5:
        return nom_trig2017[4]
    if lep_pt < 200 and lep_pt > 120 and lep_eta < -1.5 and lep_eta > -2.5:
        return nom_trig2017[5]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < -0.5 and lep_eta > -1.5:
        return nom_trig2017[6]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 0.5 and lep_eta > -0.5:
        return nom_trig2017[7]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 1.5 and lep_eta > 0.5:
        return nom_trig2017[8]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return nom_trig2017[9]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -1.5 and lep_eta > -2.5:
        return nom_trig2017[10]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -0.5 and lep_eta > -1.5:
        return nom_trig2017[11]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 0.5 and lep_eta > -0.5:
        return nom_trig2017[12]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 1.5 and lep_eta > 0.5:
        return nom_trig2017[13]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return nom_trig2017[14]
    else:
        return 1


def applyTriggerSF_2016(lep_pt,lep_eta):
    if lep_pt < 2000 and lep_pt > 200 and lep_eta < -1.5 and lep_eta > -2.5:
        return nom_trig2016[0]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < -0.5 and lep_eta > -1.5:
        return nom_trig2016[1]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 0.5 and lep_eta > -0.5:
        return nom_trig2016[2]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 1.5 and lep_eta > 0.5:
        return nom_trig2016[3]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 2.5 and lep_eta > 1.5:
        return nom_trig2016[4]
    if lep_pt < 200 and lep_pt > 120 and lep_eta < -1.5 and lep_eta > -2.5:
        return nom_trig2016[5]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < -0.5 and lep_eta > -1.5:
        return nom_trig2016[6]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 0.5 and lep_eta > -0.5:
        return nom_trig2016[7]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 1.5 and lep_eta > 0.5:
        return nom_trig2016[8]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return nom_trig2016[9]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -1.5 and lep_eta > -2.5:
        return nom_trig2016[10]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -0.5 and lep_eta > -1.5:
        return nom_trig2016[11]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 0.5 and lep_eta > -0.5:
        return nom_trig2016[12]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 1.5 and lep_eta > 0.5:
        return nom_trig2016[13]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return nom_trig2016[14]
    else:
        return 1



def applyTriggerSF_up_2018(lep_pt,lep_eta):
    if lep_pt < 2000 and lep_pt > 200 and lep_eta < -1.5 and lep_eta > -2.5:
        return up_trig[0]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < -0.5 and lep_eta > -1.5:
        return up_trig[1]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 0.5 and lep_eta > -0.5:
        return up_trig[2]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 1.5 and lep_eta > 0.5:
        return up_trig[3]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 2.5 and lep_eta > 1.5:
        return up_trig[4]
    if lep_pt < 200 and lep_pt > 120 and lep_eta < -1.5 and lep_eta > -2.5:
        return up_trig[5]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < -0.5 and lep_eta > -1.5:
        return up_trig[6]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 0.5 and lep_eta > -0.5:
        return up_trig[7]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 1.5 and lep_eta > 0.5:
        return up_trig[8]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return up_trig[9]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -1.5 and lep_eta > -2.5:
        return up_trig[10]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -0.5 and lep_eta > -1.5:
        return up_trig[11]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 0.5 and lep_eta > -0.5:
        return up_trig[12]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 1.5 and lep_eta > 0.5:
        return up_trig[13]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return up_trig[14]
    else:
        return 1


def applyTriggerSF_up_2017(lep_pt,lep_eta):
    if lep_pt < 2000 and lep_pt > 200 and lep_eta < -1.5 and lep_eta > -2.5:
        return up_trig2017[0]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < -0.5 and lep_eta > -1.5:
        return up_trig2017[1]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 0.5 and lep_eta > -0.5:
        return up_trig2017[2]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 1.5 and lep_eta > 0.5:
        return up_trig2017[3]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 2.5 and lep_eta > 1.5:
        return up_trig2017[4]
    if lep_pt < 200 and lep_pt > 120 and lep_eta < -1.5 and lep_eta > -2.5:
        return up_trig2017[5]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < -0.5 and lep_eta > -1.5:
        return up_trig2017[6]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 0.5 and lep_eta > -0.5:
        return up_trig2017[7]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 1.5 and lep_eta > 0.5:
        return up_trig2017[8]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return up_trig2017[9]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -1.5 and lep_eta > -2.5:
        return up_trig2017[10]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -0.5 and lep_eta > -1.5:
        return up_trig2017[11]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 0.5 and lep_eta > -0.5:
        return up_trig2017[12]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 1.5 and lep_eta > 0.5:
        return up_trig2017[13]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return up_trig2017[14]
    else:
        return 1

def applyTriggerSF_up_2016(lep_pt,lep_eta):
    if lep_pt < 2000 and lep_pt > 200 and lep_eta < -1.5 and lep_eta > -2.5:
        return up_trig2016[0]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < -0.5 and lep_eta > -1.5:
        return up_trig2016[1]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 0.5 and lep_eta > -0.5:
        return up_trig2016[2]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 1.5 and lep_eta > 0.5:
        return up_trig2016[3]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 2.5 and lep_eta > 1.5:
        return up_trig2016[4]
    if lep_pt < 200 and lep_pt > 120 and lep_eta < -1.5 and lep_eta > -2.5:
        return up_trig2016[5]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < -0.5 and lep_eta > -1.5:
        return up_trig2016[6]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 0.5 and lep_eta > -0.5:
        return up_trig2016[7]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 1.5 and lep_eta > 0.5:
        return up_trig2016[8]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return up_trig2016[9]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -1.5 and lep_eta > -2.5:
        return up_trig2016[10]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -0.5 and lep_eta > -1.5:
        return up_trig2016[11]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 0.5 and lep_eta > -0.5:
        return up_trig2016[12]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 1.5 and lep_eta > 0.5:
        return up_trig2016[13]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return up_trig2016[14]
    else:
        return 1


def applyTriggerSF_down_2018(lep_pt,lep_eta):
    if lep_pt < 2000 and lep_pt > 200 and lep_eta < -1.5 and lep_eta > -2.5:
        return down_trig[0]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < -0.5 and lep_eta > -1.5:
        return down_trig[1]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 0.5 and lep_eta > -0.5:
        return down_trig[2]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 1.5 and lep_eta > 0.5:
        return down_trig[3]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 2.5 and lep_eta > 1.5:
        return down_trig[4]
    if lep_pt < 200 and lep_pt > 120 and lep_eta < -1.5 and lep_eta > -2.5:
        return down_trig[5]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < -0.5 and lep_eta > -1.5:
        return down_trig[6]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 0.5 and lep_eta > -0.5:
        return down_trig[7]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 1.5 and lep_eta > 0.5:
        return down_trig[8]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return down_trig[9]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -1.5 and lep_eta > -2.5:
        return down_trig[10]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -0.5 and lep_eta > -1.5:
        return down_trig[11]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 0.5 and lep_eta > -0.5:
        return down_trig[12]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 1.5 and lep_eta > 0.5:
        return down_trig[13]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return down_trig[14]
    else:
        return 1


def applyTriggerSF_down_2017(lep_pt,lep_eta):
    if lep_pt < 2000 and lep_pt > 200 and lep_eta < -1.5 and lep_eta > -2.5:
        return down_trig2017[0]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < -0.5 and lep_eta > -1.5:
        return down_trig2017[1]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 0.5 and lep_eta > -0.5:
        return down_trig2017[2]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 1.5 and lep_eta > 0.5:
        return down_trig2017[3]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 2.5 and lep_eta > 1.5:
        return down_trig2017[4]
    if lep_pt < 200 and lep_pt > 120 and lep_eta < -1.5 and lep_eta > -2.5:
        return down_trig2017[5]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < -0.5 and lep_eta > -1.5:
        return down_trig2017[6]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 0.5 and lep_eta > -0.5:
        return down_trig2017[7]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 1.5 and lep_eta > 0.5:
        return down_trig2017[8]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return down_trig2017[9]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -1.5 and lep_eta > -2.5:
        return down_trig2017[10]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -0.5 and lep_eta > -1.5:
        return down_trig2017[11]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 0.5 and lep_eta > -0.5:
        return down_trig2017[12]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 1.5 and lep_eta > 0.5:
        return down_trig2017[13]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return down_trig2017[14]
    else:
        return 1


def applyTriggerSF_down_2016(lep_pt,lep_eta):
    if lep_pt < 2000 and lep_pt > 200 and lep_eta < -1.5 and lep_eta > -2.5:
        return down_trig2016[0]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < -0.5 and lep_eta > -1.5:
        return down_trig2016[1]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 0.5 and lep_eta > -0.5:
        return down_trig2016[2]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 1.5 and lep_eta > 0.5:
        return down_trig2016[3]
    elif lep_pt < 2000 and lep_pt > 200 and lep_eta < 2.5 and lep_eta > 1.5:
        return down_trig2016[4]
    if lep_pt < 200 and lep_pt > 120 and lep_eta < -1.5 and lep_eta > -2.5:
        return down_trig2016[5]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < -0.5 and lep_eta > -1.5:
        return down_trig2016[6]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 0.5 and lep_eta > -0.5:
        return down_trig2016[7]
    elif lep_pt < 200 and lep_pt > 120 and lep_eta < 1.5 and lep_eta > 0.5:
        return down_trig2016[8]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return down_trig2016[9]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -1.5 and lep_eta > -2.5:
        return down_trig2016[10]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < -0.5 and lep_eta > -1.5:
        return down_trig2016[11]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 0.5 and lep_eta > -0.5:
        return down_trig2016[12]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 1.5 and lep_eta > 0.5:
        return down_trig2016[13]
    elif lep_pt < 120 and lep_pt > 30 and lep_eta < 2.5 and lep_eta > 1.5:
        return down_trig2016[14]
    else:
        return 1



def get_templates(years, channels, samples, samples_dir, regions_sel, model_path, add_fake=False):
    """
    Postprocesses the parquets by applying preselections, and fills templates for different regions.

    Args
        years [list]: years to postprocess (e.g. ["2016APV", "2016"])
        ch [list]: channels to postprocess (e.g. ["ele", "mu"])
        samples [list]: samples to postprocess (e.g. ["ggF", "TTbar", "Data"])
        samples_dir [dict]: points to the path of the parquets for each region
        regions_sel [dict]: key is the name of the region; value is the selection (e.g. `{"pass": (THWW>0.90)}`)
        model_path [str]: path to the ParT finetuned model.onnx
        add_fake [Bool]: if True will include Fake as an additional sample in the output hists

    Returns
        a dict() object hists[region] that contains histograms with 4 axes (Sample, Systematic, Region, mass_observable)

    """


    # add extra selections to preselection #note had changed to 120 for S/B and then forgot to change back and then got zero entries in upper bins
    presel = { "mu": { "fj_mass": "fj_mass > 40",}, "ele": {"fj_mass": "fj_mass > 40",}, }

    #mass_binning = [40,70,120,180]
    #mass_binning = [40,70,100,130,180]
        
    mass_binning = [40, 70, 105, 180]

    
    hists = hist2.Hist(
        hist2.axis.StrCategory([], name="Sample", growth=True), hist2.axis.StrCategory([], name="Systematic", growth=True), hist2.axis.StrCategory([], name="Region", growth=True),
        hist2.axis.Variable(
            #list(range(55, 255, mass_binning)),
            mass_binning, name="mass_observable", label=r"V reconstructed mass [GeV]", overflow=True,
        ), storage=hist2.storage.Weight(),
    )

    SYST_DICT = get_systematic_dict(years)

    for year in years:  # e.g. 2018, 2017, 2016APV, 2016

        if year == '2018':
            CALIBRATED_FACTOR = 1.1
        elif year == '2017':
            CALIBRATED_FACTOR = 1.043
        elif year == '2016':
            CALIBRATED_FACTOR = 1.129
        else:
            CALIBRATED_FACTOR = 1.1
        
        print('year, factor', year, CALIBRATED_FACTOR)


        
        for ch in channels:  # e.g. mu, ele
            logging.info(f"Processing year {year} and {ch} channel")

            with open("../fileset/luminosity.json") as f:
                luminosity = json.load(f)[ch][year]

            for sample in os.listdir(samples_dir[year]):

                sample_to_use = get_common_sample_name(sample)

                if sample_to_use not in samples:
                    continue

                is_data = True if sample_to_use == "Data" else False

                logging.info(f"Finding {sample} samples and should combine them under {sample_to_use}")

                out_files = f"{samples_dir[year]}/{sample}/outfiles/"
                parquet_files = glob.glob(f"{out_files}/*_{ch}.parquet")
                pkl_files = glob.glob(f"{out_files}/*.pkl")

                if not parquet_files:
                    logging.info(f"No parquet file for {sample}")
                    continue

                try:
                    data = pd.read_parquet(parquet_files)
                except pyarrow.lib.ArrowInvalid:  # empty parquet because no event passed selection
                    continue

                if len(data) == 0:
                    continue

                data["THWW"] = get_finetuned_score(data, model_path)
                data = data[data.columns.drop(list(data.filter(regex="hidNeuron")))]

                for selection in presel[ch]:
                    logging.info(f"Applying {selection} selection on {len(data)} events")
                    data = data.query(presel[ch][selection])

#********************************************************************************************************
                    if not is_data: #should rename processor variables....

                  #      if year == '2016APV':
                  #          data["fj_massJMS_" + "2016" + "_up"] = data['fj_massJMS_up']
                  #          data["fj_massJMS_" + "2016" + "_down"] = data['fj_massJMS_down']  
                  #          data["fj_massJMR_" + "2016" + "_up"] = data['fj_massJMR_up']
                  #          data["fj_massJMR_" + "2016" + "_down"] = data['fj_massJMR_down'] 
                  #      else:
                  #          data["fj_massJMS_" + year + "_up"] = data['fj_massJMS_up']
                  #          data["fj_massJMS_" + year + "_down"] = data['fj_massJMS_down']  
                  #          data["fj_massJMR_" + year + "_up"] = data['fj_massJMR_up']
                  #          data["fj_massJMR_" + year + "_down"] = data['fj_massJMR_down']  
#up and down seem flipped in parquets
                        
                        if year == '2016APV':
                            data["fj_massJMS_" + "2016" + "_down"] = data['fj_massJMS_up']
                            data["fj_massJMS_" + "2016" + "_up"] = data['fj_massJMS_down']  
                            data["fj_massJMR_" + "2016" + "_down"] = data['fj_massJMR_up']
                            data["fj_massJMR_" + "2016" + "_up"] = data['fj_massJMR_down'] 
                        else:
                            data["fj_massJMS_" + year + "_down"] = data['fj_massJMS_up']
                            data["fj_massJMS_" + year + "_up"] = data['fj_massJMS_down']  
                            data["fj_massJMR_" + year + "_down"] = data['fj_massJMR_up']
                            data["fj_massJMR_" + year + "_up"] = data['fj_massJMR_down']  

                    
                    
                    
                    if not is_data:

                        data['met_pt_UES_up'] = data['ues_up']
                        data['met_pt_UES_down'] = data['ues_down'] #to do: reame in processor to elim. this step

                        data['temp_JESdown'] = data['met_pt_JES_down']
                        data['temp_JESup'] = data['met_pt_JES_up']
                        data[['met_pt_JES_down', 'met_pt_JES_up']]= data[['temp_JESup', 'temp_JESdown']]
                        data['temp_JERdown'] = data['met_pt_JER_down']
                        data['temp_JERup'] = data['met_pt_JER_up']
                        data[['met_pt_JER_down', 'met_pt_JER_up']]= data[['temp_JERup', 'temp_JERdown']]
                        data['temp_JES_FlavorQCD_down'] = data['met_pt_JES_FlavorQCD_down']
                        data['temp_JES_FlavorQCD_up'] = data['met_pt_JES_FlavorQCD_up']
                        data[['met_pt_JES_FlavorQCD_down', 'met_pt_JES_FlavorQCD_up']]= data[['temp_JES_FlavorQCD_up', 'temp_JES_FlavorQCD_down']]
                        data['temp_JESRelativeBal_down'] = data['met_pt_JES_RelativeBal_down']
                        data['temp_JESRelativeBal_up'] = data['met_pt_JES_RelativeBal_up']
                        data[['met_pt_JES_RelativeBal_down', 'met_pt_JES_RelativeBal_up']]= data[['temp_JESRelativeBal_up', 'temp_JESRelativeBal_down']]
                        data['temp_JES_HF_down'] = data['met_pt_JES_HF_down']
                        data['temp_JES_HF_up'] = data['met_pt_JES_HF_up']
                        data[['met_pt_JES_HF_down', 'met_pt_JES_HF_up']]= data[['temp_JES_HF_up', 'temp_JES_HF_down']]
                        data['temp_JES_BBEC1_down'] = data['met_pt_JES_BBEC1_down']
                        data['temp_JES_BBEC1_up'] = data['met_pt_JES_BBEC1_up']
                        data[['met_pt_JES_BBEC1_down', 'met_pt_JES_BBEC1_up']]= data[['temp_JES_BBEC1_up', 'temp_JES_BBEC1_down']]
                        data['temp_JES_EC2_down'] = data['met_pt_JES_EC2_down']
                        data['temp_JES_EC2_up'] = data['met_pt_JES_EC2_up']
                        data[['met_pt_JES_EC2_down', 'met_pt_JES_EC2_up']]= data[['temp_JES_EC2_up', 'temp_JES_EC2_down']]
                        data['temp_JES_Absolute_down'] = data['met_pt_JES_Absolute_down']
                        data['temp_JES_Absolute_up'] = data['met_pt_JES_Absolute_up']
                        data[['met_pt_JES_Absolute_down', 'met_pt_JES_Absolute_up']]= data[['temp_JES_Absolute_up', 'temp_JES_Absolute_down']]
                        data['temp_JES_Total_down'] = data['met_pt_JES_Total_down']
                        data['temp_JES_Total_up'] = data['met_pt_JES_Total_up']
                        data[['met_pt_JES_Total_down', 'met_pt_JES_Total_up']]= data[['temp_JES_Total_up', 'temp_JES_Total_down']]

                        if year == '2018':
                            data['temp_JES_BBEC1_2018_down'] = data['met_pt_JES_BBEC1_2018_down']
                            data['temp_JES_BBEC1_2018_up'] = data['met_pt_JES_BBEC1_2018_up']
                            data[['met_pt_JES_BBEC1_2018_down', 'met_pt_JES_BBEC1_2018_up']]= data[['temp_JES_BBEC1_2018_up', 'temp_JES_BBEC1_2018_down']]
                            data['temp_JES_RelativeSample_2018_down'] = data['met_pt_JES_RelativeSample_2018_down']
                            data['temp_JES_RelativeSample_2018_up'] = data['met_pt_JES_RelativeSample_2018_up']
                            data[['met_pt_JES_RelativeSample_2018_down', 'met_pt_JES_RelativeSample_2018_up']]= data[['temp_JES_RelativeSample_2018_up', 'temp_JES_RelativeSample_2018_down']]
                            data['temp_JES_EC2_2018_down'] = data['met_pt_JES_EC2_2018_down']
                            data['temp_JES_EC2_2018_up'] = data['met_pt_JES_EC2_2018_up']
                            data[['met_pt_JES_EC2_2018_down', 'met_pt_JES_EC2_2018_up']]= data[['temp_JES_EC2_2018_up', 'temp_JES_EC2_2018_down']]
                            data['temp_JES_HF_2018_down'] = data['met_pt_JES_HF_2018_down']
                            data['temp_JES_HF_2018_up'] = data['met_pt_JES_HF_2018_up']
                            data[['met_pt_JES_HF_2018_down', 'met_pt_JES_HF_2018_up']]= data[['temp_JES_HF_2018_up', 'temp_JES_HF_2018_down']]
                            data['temp_JES_Absolute_2018_down'] = data['met_pt_JES_Absolute_2018_down']
                            data['temp_JES_Absolute_2018_up'] = data['met_pt_JES_Absolute_2018_up']
                            data[['met_pt_JES_Absolute_2018_down', 'met_pt_JES_Absolute_2018_up']]= data[['temp_JES_Absolute_2018_up', 'temp_JES_Absolute_2018_down']]

                        elif year == '2017':
                            data['temp_JES_BBEC1_2017_down'] = data['met_pt_JES_BBEC1_2017_down']
                            data['temp_JES_BBEC1_2017_up'] = data['met_pt_JES_BBEC1_2017_up']
                            data[['met_pt_JES_BBEC1_2017_down', 'met_pt_JES_BBEC1_2017_up']]= data[['temp_JES_BBEC1_2017_up', 'temp_JES_BBEC1_2017_down']]
                            data['temp_JES_RelativeSample_2017_down'] = data['met_pt_JES_RelativeSample_2017_down']
                            data['temp_JES_RelativeSample_2017_up'] = data['met_pt_JES_RelativeSample_2017_up']
                            data[['met_pt_JES_RelativeSample_2017_down', 'met_pt_JES_RelativeSample_2017_up']]= data[['temp_JES_RelativeSample_2017_up', 'temp_JES_RelativeSample_2017_down']]
                            data['temp_JES_EC2_2017_down'] = data['met_pt_JES_EC2_2017_down']
                            data['temp_JES_EC2_2017_up'] = data['met_pt_JES_EC2_2017_up']
                            data[['met_pt_JES_EC2_2017_down', 'met_pt_JES_EC2_2017_up']]= data[['temp_JES_EC2_2017_up', 'temp_JES_EC2_2017_down']]
                            data['temp_JES_HF_2017_down'] = data['met_pt_JES_HF_2017_down']
                            data['temp_JES_HF_2017_up'] = data['met_pt_JES_HF_2017_up']
                            data[['met_pt_JES_HF_2017_down', 'met_pt_JES_HF_2017_up']]= data[['temp_JES_HF_2017_up', 'temp_JES_HF_2017_down']]
                            data['temp_JES_Absolute_2017_down'] = data['met_pt_JES_Absolute_2017_down']
                            data['temp_JES_Absolute_2017_up'] = data['met_pt_JES_Absolute_2017_up']
                            data[['met_pt_JES_Absolute_2017_down', 'met_pt_JES_Absolute_2017_up']]= data[['temp_JES_Absolute_2017_up', 'temp_JES_Absolute_2017_down']]

                        elif year == '2016' or year == '2016APV':
                            data['temp_JES_BBEC1_2016_down'] = data['met_pt_JES_BBEC1_2016_down']
                            data['temp_JES_BBEC1_2016_up'] = data['met_pt_JES_BBEC1_2016_up']
                            data[['met_pt_JES_BBEC1_2016_down', 'met_pt_JES_BBEC1_2016_up']]= data[['temp_JES_BBEC1_2016_up', 'temp_JES_BBEC1_2016_down']]
                            data['temp_JES_RelativeSample_2016_down'] = data['met_pt_JES_RelativeSample_2016_down']
                            data['temp_JES_RelativeSample_2016_up'] = data['met_pt_JES_RelativeSample_2016_up']
                            data[['met_pt_JES_RelativeSample_2016_down', 'met_pt_JES_RelativeSample_2016_up']]= data[['temp_JES_RelativeSample_2016_up', 'temp_JES_RelativeSample_2016_down']]
                            data['temp_JES_EC2_2016_down'] = data['met_pt_JES_EC2_2016_down']
                            data['temp_JES_EC2_2016_up'] = data['met_pt_JES_EC2_2016_up']
                            data[['met_pt_JES_EC2_2016_down', 'met_pt_JES_EC2_2016_up']]= data[['temp_JES_EC2_2016_up', 'temp_JES_EC2_2016_down']]
                            data['temp_JES_HF_2016_down'] = data['met_pt_JES_HF_2016_down']
                            data['temp_JES_HF_2016_up'] = data['met_pt_JES_HF_2016_up']
                            data[['met_pt_JES_HF_2016_down', 'met_pt_JES_HF_2016_up']]= data[['temp_JES_HF_2016_up', 'temp_JES_HF_2016_down']]
                            data['temp_JES_Absolute_2016_down'] = data['met_pt_JES_Absolute_2016_down']
                            data['temp_JES_Absolute_2016_up'] = data['met_pt_JES_Absolute_2016_up']
                            data[['met_pt_JES_Absolute_2016_down', 'met_pt_JES_Absolute_2016_up']]= data[['temp_JES_Absolute_2016_up', 'temp_JES_Absolute_2016_down']]

#********************************************************************************************************
                # get the xsecweight
                xsecweight, sumgenweights, sumpdfweights, sumscaleweights = get_xsecweight( pkl_files, year, sample, sample_to_use, is_data, luminosity)

                for region, region_sel in regions_sel.items():  # e.g. pass, fail, top control region, etc.
                #need to apply the V calibration only when making a cut on V tagger; currently the TTbar CR has no cut on tagger, so don't apply it
#WFACTOR        2016: 1.129      2016APV: 1.1         2017: 1.043         2018: 1.027
                    #print('region', region)
                    if region == 'SR1':
                        WFACTOR =  CALIBRATED_FACTOR
                    if region == 'TopCR':
                        WFACTOR = 1
                    else:
                        WFACTOR = 1
#**************************************************************************************
                    df = data.copy()
                    logging.info(f"Applying {region} selection on {len(df)} events")
                    df = df.query(region_sel)
                    logging.info(f"Will fill the histograms with the remaining {len(df)} events")

                    # ------------------- Nominal -------------------
                    if is_data:
                        nominal = np.ones_like(df["fj_pt"])  # for data (nominal is 1)
                    else:
                        nominal = df[f"weight_{ch}"] * xsecweight * df["weight_btag"] * WFACTOR


                        #hacky way to include SF
                        if ch == 'ele':
                            if year == '2018':
                                df['temp'] = df.apply(lambda row:applyTriggerSF_2018(row['lep_pt'],row['lep_eta']),axis=1)
                                nominal *=  df['temp']
                                df.drop(columns=['temp'],axis=1)
                            elif year == '2017':
                                df['temp'] = df.apply(lambda row:applyTriggerSF_2017(row['lep_pt'],row['lep_eta']),axis=1)
                                nominal *=  df['temp']
                                df.drop(columns=['temp'],axis=1)
                            else:
                                df['temp'] = df.apply(lambda row:applyTriggerSF_2016(row['lep_pt'],row['lep_eta']),axis=1)
                                nominal *=  df['temp']
                                df.drop(columns=['temp'],axis=1)


                        if sample_to_use == "TTbar":
                            nominal *= df["top_reweighting"]
                    ###################################
                    if sample_to_use == "EWKvjets":
                        threshold = 20
                        df = df[nominal < threshold]
                        nominal = nominal[nominal < threshold]
                    ###################################

                    hists.fill( Sample=sample_to_use, Systematic="nominal", Region=region, mass_observable=df["fj_mass"], weight=nominal,)
#*****************************histo for up and down trigger scale factor for electron only

                  
                    for syst, (yrs, smpls, var) in SYST_DICT["TRIGGER_systs"].items(): #this dictionary only applies it to electron

                        if year == '2018':
                            if (sample_to_use in smpls) and (year in yrs) and (ch in var):
                                    df['weight_up'] = df.apply(lambda row:applyTriggerSF_up_2018(row['lep_pt'],row['lep_eta']),axis=1)
                                    df["weight_down"] = df.apply(lambda row:applyTriggerSF_down_2018(row['lep_pt'],row['lep_eta']),axis=1)
                                    shape_up=nominal*df['weight_up']
                                    shape_down=nominal*df['weight_down']
                                    df.drop(columns=['weight_up'],axis=1)
                                    df.drop(columns=['weight_down'],axis=1)
                            else:
                                    shape_up = nominal
                                    shape_down = nominal

                        elif year == '2017':
                            if (sample_to_use in smpls) and (year in yrs) and (ch in var):
                                    df['weight_up'] = df.apply(lambda row:applyTriggerSF_up_2017(row['lep_pt'],row['lep_eta']),axis=1)
                                    df["weight_down"] = df.apply(lambda row:applyTriggerSF_down_2017(row['lep_pt'],row['lep_eta']),axis=1)
                                    shape_up=nominal*df['weight_up']
                                    shape_down=nominal*df['weight_down']
                                    df.drop(columns=['weight_up'],axis=1)
                                    df.drop(columns=['weight_down'],axis=1)
                            else:
                                    shape_up = nominal
                                    shape_down = nominal

                        else:
                            if (sample_to_use in smpls) and (year in yrs) and (ch in var):
                                    df['weight_up'] = df.apply(lambda row:applyTriggerSF_up_2016(row['lep_pt'],row['lep_eta']),axis=1)
                                    df["weight_down"] = df.apply(lambda row:applyTriggerSF_down_2016(row['lep_pt'],row['lep_eta']),axis=1)
                                    shape_up=nominal*df['weight_up']
                                    shape_down=nominal*df['weight_down']
                                    df.drop(columns=['weight_up'],axis=1)
                                    df.drop(columns=['weight_down'],axis=1)
                            else:
                                    shape_up = nominal
                                    shape_down = nominal
                        

                        
                        hists.fill( Sample=sample_to_use, Systematic=f"{syst}_up", Region=region, mass_observable=df["fj_mass"], weight=shape_up )
                        hists.fill( Sample=sample_to_use, Systematic=f"{syst}_down", Region=region, mass_observable=df["fj_mass"],weight=shape_down )
    
#*****************************************************************************************
                    # ------------------- PDF acceptance -------------------
                    """
                    For the PDF acceptance uncertainty:
                    - store 103 variations. 0-100 PDF values, The last two values: alpha_s variations.
                    - you just sum the yield difference from the nominal in quadrature to get the total uncertainty.
                    e.g. https://github.com/LPC-HH/HHLooper/blob/master/python/prepare_card_SR_final.py#L258
                    and https://github.com/LPC-HH/HHLooper/blob/master/app/HHLooper.cc#L1488
                    """
                    # if sample_to_use in sigs:
                    if (sample_to_use in sigs + ["WJetsLNu", "TTbar"]) and (sample != "ST_s-channel_4f_hadronicDecays"):
                        pdfweights = []
                        for weight_i in sumpdfweights:
                            # noqa: get the normalization factor per variation i (ratio of sumpdfweights_i/sumgenweights)
                            R_i = sumpdfweights[weight_i] / sumgenweights
                            pdfweight = df[f"weight_pdf{weight_i}"].values * nominal / R_i
                            pdfweights.append(pdfweight)
                        pdfweights = np.swapaxes(np.array(pdfweights), 0, 1)  # so that the shape is (# events, variation)
                        abs_unc = np.linalg.norm((pdfweights - nominal.values.reshape(-1, 1)), axis=1)
                        # cap at 100% uncertainty
                        rel_unc = np.clip(abs_unc / nominal, 0, 1)
                        shape_up = nominal * (1 + rel_unc)
                        shape_down = nominal * (1 - rel_unc)
                    else:
                        shape_up = nominal
                        shape_down = nominal

                    hists.fill(Sample=sample_to_use, Systematic="weight_pdf_acceptance_up", Region=region, mass_observable=df["fj_mass"], weight=shape_up, )
                    hists.fill( Sample=sample_to_use, Systematic="weight_pdf_acceptance_down", Region=region, mass_observable=df["fj_mass"], weight=shape_down,)

                    # ------------------- QCD scale -------------------
                    """
                    For the QCD acceptance uncertainty:
                    - we save the individual weights [0, 1, 3, 5, 7, 8]
                    - postprocessing: we obtain sum_sumlheweight
                    - postprocessing: we obtain LHEScaleSumw: sum_sumlheweight[i] / sum_sumgenweight
                    - postprocessing:
                    obtain histograms for 0, 1, 3, 5, 7, 8 and 4: h0, h1, ... respectively
                    weighted by scale_0, scale_1, etc
                    and normalize them by  (xsec * luminosity) / LHEScaleSumw[i]
                    - then, take max/min of h0, h1, h3, h5, h7, h8 w.r.t h4: h_up and h_dn
                    - the uncertainty is the nominal histogram * h_up / h4
                    """
                    if (sample_to_use in sigs + ["WJetsLNu", "TTbar", "SingleTop"]) and (sample != "ST_s-channel_4f_hadronicDecays" ):
                        R_4 = sumscaleweights[4] / sumgenweights
                        scaleweight_4 = df["weight_scale4"].values * nominal / R_4

                        scaleweights = []
                        for weight_i in sumscaleweights:
                            if weight_i == 4:
                                continue
                            # get the normalization factor per variation i (ratio of sumscaleweights_i/sumgenweights)
                            R_i = sumscaleweights[weight_i] / sumgenweights
                            scaleweight_i = df[f"weight_scale{weight_i}"].values * nominal / R_i
                            scaleweights.append(scaleweight_i)

                        scaleweights = np.array(scaleweights)
                        scaleweights = np.swapaxes(np.array(scaleweights), 0, 1  )  # so that the shape is (# events, variation)
                        # TODO: debug
                        shape_up = nominal * np.max(scaleweights, axis=1) / scaleweight_4
                        shape_down = nominal * np.min(scaleweights, axis=1) / scaleweight_4
                    else:
                        shape_up = nominal
                        shape_down = nominal

                    hists.fill(Sample=sample_to_use, Systematic="weight_qcd_scale_up", Region=region, mass_observable=df["fj_mass"],  weight=shape_up,)
                    hists.fill( Sample=sample_to_use, Systematic="weight_qcd_scale_down", Region=region, mass_observable=df["fj_mass"], weight=shape_down, )

                    # ------------------- Top pt reweighting systematic  -------------------

                    if sample_to_use == "TTbar":
                        # first remove the reweighting effect
                        nominal_noreweighting = nominal / df["top_reweighting"]

                        shape_up = nominal_noreweighting * (df["top_reweighting"] ** 2)  # "up" is twice the correction
                        shape_down = nominal_noreweighting  # "down" is no correction
                    else:
                        shape_up = nominal
                        shape_down = nominal

                    hists.fill( Sample=sample_to_use, Systematic="top_reweighting_up", Region=region, mass_observable=df["fj_mass"], weight=shape_up,)
                    hists.fill( Sample=sample_to_use, Systematic="top_reweighting_down", Region=region, mass_observable=df["fj_mass"], weight=shape_down,)

                    # ------------------- Common systematics  -------------------

#nominal has event weight, but event weight already has pileup weight in it since it is a product of various event weights, so i guess that is why farouk only has xsec weight.
                        #nominal = df[f"weight_{ch}"] * xsecweight * df["weight_btag"]
                    for syst, (yrs, smpls, var) in SYST_DICT["common"].items():
                        #print('syst', syst)
                        if (sample_to_use in smpls) and (year in yrs) and (ch in var):
                            shape_up = df[var[ch] + "Up"] * xsecweight * df["weight_btag"] * WFACTOR
                            shape_down = df[var[ch] + "Down"] * xsecweight * df["weight_btag"] * WFACTOR
                            if sample_to_use == "TTbar":
                                shape_up *= df["top_reweighting"]
                                shape_down *= df["top_reweighting"]

                        else:
                            shape_up = nominal
                            shape_down = nominal
                        hists.fill( Sample=sample_to_use, Systematic=f"{syst}_up", Region=region, mass_observable=df["fj_mass"], weight=shape_up, )
                        hists.fill( Sample=sample_to_use, Systematic=f"{syst}_down", Region=region, mass_observable=df["fj_mass"], weight=shape_down, )

              #****************************************jmr jms:
                    for syst, (yrs, smpls, var) in SYST_DICT["JEC_systs_MASS"].items():
                        if (sample_to_use in smpls) and (year in yrs) and (ch in var):            
                            shape_up = df["fj_mass" + var[ch] +  "_up"]   
                            shape_down = df["fj_mass" + var[ch] + "_down"] 
                        else:
                            shape_up = df['fj_mass']
                            shape_down = df['fj_mass'] 
                        hists.fill(Sample=sample_to_use, Systematic=f"{syst}_up", Region=region, mass_observable=shape_up, weight=nominal,)
                        hists.fill(Sample=sample_to_use, Systematic=f"{syst}_down", Region=region, mass_observable=shape_down, weight=nominal,)
     #****************************************btag:             
                    for syst, (yrs, smpls, var) in SYST_DICT["btag1"].items():  #this works %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
                        if (sample_to_use in smpls) and (year in yrs) and (ch in var):
                            shape_up = df[var[ch] + "Up"]  * xsecweight * df[f"weight_{ch}"] * WFACTOR
                            shape_down = df[var[ch] + "Down"]  * xsecweight * df[f"weight_{ch}"] * WFACTOR
                        else:                       
                            shape_up = df['fj_mass']
                            shape_down = df['fj_mass']
                        if sample_to_use == "TTbar":
                            shape_up *= df["top_reweighting"]
                            shape_down *= df["top_reweighting"]

                        hists.fill(Sample=sample_to_use, Systematic=f"{syst}_up", Region=region, mass_observable=df["fj_mass"], weight=shape_up,)
                        hists.fill(Sample=sample_to_use, Systematic=f"{syst}_down", Region=region, mass_observable=df["fj_mass"], weight=shape_down,)

                   #****************************************btag by year:
                    for syst, (yrs, smpls, var) in SYST_DICT["btag2"].items(): 
                        if (sample_to_use in smpls) and (year in yrs) and (ch in var):
                            #print('btag2 syst', syst, sample_to_use,year,ch)
                            #print('df[var[ch]', (df[var[ch]]))
                            shape_up = df[var[ch] + "Up"]  * xsecweight * df[f"weight_{ch}"] * WFACTOR
                            shape_down = df[var[ch] + "Down"] * xsecweight * df[f"weight_{ch}"] * WFACTOR            
                            if sample_to_use == "TTbar":
                                shape_up *= df["top_reweighting"]
                                shape_down *= df["top_reweighting"]
                            hists.fill(Sample=sample_to_use, Systematic=f"{syst}_up", Region=region, mass_observable=df["fj_mass"], weight=shape_up)
                            hists.fill(Sample=sample_to_use, Systematic=f"{syst}_down", Region=region, mass_observable=df["fj_mass"], weight=shape_down)
                        else:  #NOTE: don't apply top reweighting below b/c nominal already had it applied for ttbar samples
                            shape_up =  nominal
                            shape_down = nominal
                            hists.fill(Sample=sample_to_use, Systematic=f"{syst}_up", Region=region, mass_observable=df["fj_mass"], weight=shape_up)
                            hists.fill(Sample=sample_to_use, Systematic=f"{syst}_down", Region=region, mass_observable=df["fj_mass"], weight=shape_down)
      

                #end of: for region, region_sel in regions_sel.items():
                # ------------------- individual sources of JES -------------------
                #HERE IS A NEW REGION SELECTION, and NEW definition of nominal **********************************
                """We apply the jet pt cut on the up/down variations. Must loop over systematics first."""
                for syst, (yrs, smpls, var) in SYST_DICT["JEC"].items():
                    for variation in ["up", "down"]:
                        for region, region_sel in regions_sel.items():  # e.g. pass, fail, top control region, etc.
                            if region == 'SR1':
                                WFACTOR =  CALIBRATED_FACTOR
                            if region == 'TopCR':
                                WFACTOR = 1
                            else:
                                WFACTOR = 1
                            if (sample_to_use in smpls) and (year in yrs) and (ch in var):
                                region_sel = region_sel.replace("fj_pt", "fj_pt" + var[ch] + f"_{variation}")
                                region_sel = region_sel.replace("met_pt", "met_pt_" + var[ch] + f"_{variation}")

                                region_sel = region_sel.replace("numberBJets_Medium_OutsideFatJets", "numberBJets_" + var[ch] + f"_{variation}")

                                #print('region_sel', region_sel)
                            df = data.copy()
                            df = df.query(region_sel)
                            # ------------------- Nominal -------------------
                            if is_data:
                                nominal = np.ones_like(df["fj_pt"])  # for data (nominal is 1)
                            else:
                                nominal = df[f"weight_{ch}"] * xsecweight * df["weight_btag"] * WFACTOR

                            if sample_to_use == "TTbar":
                                nominal *= df["top_reweighting"]
                            if sample_to_use == "EWKvjets":
                                threshold = 20
                                df = df[nominal < threshold]
                                nominal = nominal[nominal < threshold]

                            if (sample_to_use in smpls) and (year in yrs) and (ch in var):
                                shape_variation = df["fj_mass"] # + var[ch] + f"_{variation}"]
                            else:
                                shape_variation = df["fj_mass"]

                            hists.fill( Sample=sample_to_use, Systematic=f"{syst}_{variation}", Region=region, mass_observable=shape_variation, weight=nominal,)

                for syst, (yrs, smpls, var) in SYST_DICT["UES_systs"].items():
                    #print('variation', variation)
                    for variation in ["up", "down"]:
                        for region, region_sel in regions_sel.items():  # e.g. pass, fail, top control region, etc.
                            #print('region', region)
                            if region == 'SR1':
                               WFACTOR =  CALIBRATED_FACTOR
                            if region == 'TopCR':
                                WFACTOR = 1
                            else:
                                WFACTOR = 1

                            if (sample_to_use in smpls) and (year in yrs) and (ch in var):
                                region_sel = region_sel.replace("met_pt", "met_pt_" + var[ch] + f"_{variation}")
                               # print('region_sel', region_sel)
                            df = data.copy()
                            df = df.query(region_sel)
                            # ------------------- Nominal -------------------
                            if is_data:
                                nominal = np.ones_like(df["fj_pt"])  # for data (nominal is 1)
                            else:
                                nominal = df[f"weight_{ch}"] * xsecweight * df["weight_btag"]* WFACTOR

                            if sample_to_use == "TTbar":
                                nominal *= df["top_reweighting"]
                            if sample_to_use == "EWKvjets":
                                threshold = 20
                                df = df[nominal < threshold]
                                nominal = nominal[nominal < threshold]

                            if (sample_to_use in smpls) and (year in yrs) and (ch in var):
                                shape_variation = df["fj_mass"]
                            else:
                                shape_variation = df["fj_mass"]

                            hists.fill( Sample=sample_to_use, Systematic=f"{syst}_{variation}", Region=region, mass_observable=shape_variation, weight=nominal,)
   
    

    for variation in ["fakes_nominal", "fakes_SF_Up", "fakes_SF_Down", "fakes_DR_Up", "fakes_DR_Down"]:
   
        for year in years:
            #data = pd.read_parquet(f"{samples_dir[year]}/fake_{year}_ele.parquet")
            #data = pd.read_parquet(f"/uscms/home/jieun201/nobackup/YOURWORKINGAREA/Fake_{year}/outfiles/0-1_ele.parquet")
            data = pd.read_parquet(f"/uscms/home/jieun201/nobackup/YOURWORKINGAREA/Fake_{year}/outfiles/{variation}_ele.parquet")
            #print('data', data)
            for selection in presel["ele"]:
                logging.info(f"Applying {selection} selection on {len(data)} events")
                data = data.query(presel["ele"][selection])
                data["THWW"] = get_finetuned_score(data, model_path)
            for region in hists.axes["Region"]:
                df = data.copy()
                logging.info(f"Applying {region} selection on {len(data)} events")
                df = df.query(regions_sel[region])
                logging.info(f"Will fill the histograms with the remaining {len(data)} events")

                if variation == "fakes_nominal":
                    hists.fill( Sample="Fake", Systematic="nominal", Region=region, mass_observable=df["fj_mass"], weight=df["event_weight"],  )
                else:
                    print('variation', variation)
                    hists.fill( Sample="Fake", Systematic=variation, Region=region, mass_observable=df["fj_mass"], weight=df["event_weight"],  )

    return hists


def fix_neg_yields(h):
    """
    Will set the bin yields of a process to 0 if the nominal yield is negative, and will
    set the yield to 0 for the full Systematic axis.
    """
    for region in h.axes["Region"]:
        for sample in h.axes["Sample"]:
            neg_bins = np.where(h[{"Sample": sample, "Systematic": "nominal", "Region": region}].values() < 0)[0]

            if len(neg_bins) > 0:
                print('got neg bins')
                print(f"{region}, {sample}, has {len(neg_bins)} bins with negative yield.. will set them to 0")

                sample_index = np.argmax(np.array(h.axes["Sample"]) == sample)
                region_index = np.argmax(np.array(h.axes["Region"]) == region)

                for neg_bin in neg_bins:
                    h.view(flow=True)[sample_index, :, region_index, neg_bin + 1].value = 1e-3
                    h.view(flow=True)[sample_index, :, region_index, neg_bin + 1].variance = 1e-3

#nom = obj[{"Region": "WJetsCR", "Systematic": "nominal", "Sample": "Fake"}]
def fix_neg_yieldsFakes(h):
    for region in h.axes["Region"]:
        neg_bins = np.where(h[{"Sample": "Fake", "Systematic": "fakes_DR_Down", "Region": region}].values() < 0)[0]
        if len(neg_bins) > 0:
            print('got neg bins')
            sample_index = np.argmax(np.array(h.axes["Sample"]) == "Fake")
            region_index = np.argmax(np.array(h.axes["Region"]) == region)
            for neg_bin in neg_bins:
                h.view(flow=True)[sample_index, :, region_index, neg_bin + 1].value = 1e-3
                h.view(flow=True)[sample_index, :, region_index, neg_bin + 1].variance = 1e-3
def fix_neg_yieldsFakes2(h):
    for region in h.axes["Region"]:
        neg_bins = np.where(h[{"Sample": "Fake", "Systematic": "fakes_SF_Down", "Region": region}].values() < 0)[0]
        if len(neg_bins) > 0:
            print('got neg bins')
            sample_index = np.argmax(np.array(h.axes["Sample"]) == "Fake")
            region_index = np.argmax(np.array(h.axes["Region"]) == region)
            for neg_bin in neg_bins:
                h.view(flow=True)[sample_index, :, region_index, neg_bin + 1].value = 1e-3
                h.view(flow=True)[sample_index, :, region_index, neg_bin + 1].variance = 1e-3

# %%
#years = ['2017','2018']
#years = ['2018']

years = ['2016', '2016APV','2017', '2018']
#years = ['2017', '2018']



outdir = 'templates'

channels = 'mu','ele'
with open("config_make_templates.yaml", "r") as stream:
    config = yaml.safe_load(stream)

if len(years) == 4:
    save_as = "Run2"
else:
    save_as = "_".join(years)

if len(channels) == 1:
    save_as += f"_{channels[0]}_"

os.system(f"mkdir -p {outdir}")

hists = get_templates(
    years,
    channels,
    config["samples"],
    config["samples_dir"],
    config["regions_sel"],
    config["model_path"],
   
)

fix_neg_yields(hists)
fix_neg_yieldsFakes(hists)
fix_neg_yieldsFakes2(hists)

with open(f"{outdir}/hists_templates_{save_as}.pkl", "wb") as fp:
    pkl.dump(hists, fp)
# Out:
# INFO:root:Processing year 2016 and mu channel
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# year, factor 2016 1.129
# INFO:root:Applying fj_mass selection on 414 events
# INFO:root:Applying SR1 selection on 414 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 414 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Applying WJetsCR selection on 414 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 12523 events
# INFO:root:Applying SR1 selection on 12521 events
# INFO:root:Will fill the histograms with the remaining 13 events
# INFO:root:Applying TopCR selection on 12521 events
# INFO:root:Will fill the histograms with the remaining 66 events
# INFO:root:Applying WJetsCR selection on 12521 events
# INFO:root:Will fill the histograms with the remaining 93 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 60653 events
# INFO:root:Applying SR1 selection on 60637 events
# INFO:root:Will fill the histograms with the remaining 52 events
# INFO:root:Applying TopCR selection on 60637 events
# INFO:root:Will fill the histograms with the remaining 553 events
# INFO:root:Applying WJetsCR selection on 60637 events
# INFO:root:Will fill the histograms with the remaining 456 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 23884 events
# INFO:root:Applying SR1 selection on 23879 events
# INFO:root:Will fill the histograms with the remaining 20 events
# INFO:root:Applying TopCR selection on 23879 events
# INFO:root:Will fill the histograms with the remaining 388 events
# INFO:root:Applying WJetsCR selection on 23879 events
# INFO:root:Will fill the histograms with the remaining 196 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 1677 events
# INFO:root:Applying SR1 selection on 1677 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 1677 events
# INFO:root:Will fill the histograms with the remaining 11 events
# INFO:root:Applying WJetsCR selection on 1677 events
# INFO:root:Will fill the histograms with the remaining 18 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 36041 events
# INFO:root:Applying SR1 selection on 36040 events
# INFO:root:Will fill the histograms with the remaining 24 events
# INFO:root:Applying TopCR selection on 36040 events
# INFO:root:Will fill the histograms with the remaining 968 events
# INFO:root:Applying WJetsCR selection on 36040 events
# INFO:root:Will fill the histograms with the remaining 298 events
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 851 events
# INFO:root:Applying SR1 selection on 851 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Applying TopCR selection on 851 events
# INFO:root:Will fill the histograms with the remaining 52 events
# INFO:root:Applying WJetsCR selection on 851 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 84 events
# INFO:root:Applying SR1 selection on 84 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 84 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Applying WJetsCR selection on 84 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 691 events
# INFO:root:Applying SR1 selection on 691 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 691 events
# INFO:root:Will fill the histograms with the remaining 39 events
# INFO:root:Applying WJetsCR selection on 691 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 135 events
# INFO:root:Applying SR1 selection on 135 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 135 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Applying WJetsCR selection on 135 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 160 events
# INFO:root:Applying SR1 selection on 160 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 160 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying WJetsCR selection on 160 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 2 events
# INFO:root:Applying SR1 selection on 2 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 2 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying WJetsCR selection on 2 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 36 events
# INFO:root:Applying SR1 selection on 36 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 36 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying WJetsCR selection on 36 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying fj_mass selection on 2534 events
# INFO:root:Applying SR1 selection on 2534 events
# INFO:root:Will fill the histograms with the remaining 41 events
# INFO:root:Applying TopCR selection on 2534 events
# INFO:root:Will fill the histograms with the remaining 16 events
# INFO:root:Applying WJetsCR selection on 2534 events
# INFO:root:Will fill the histograms with the remaining 349 events
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 9401 events
# INFO:root:Applying SR1 selection on 9401 events
# INFO:root:Will fill the histograms with the remaining 673 events
# INFO:root:Applying TopCR selection on 9401 events
# INFO:root:Will fill the histograms with the remaining 228 events
# INFO:root:Applying WJetsCR selection on 9401 events
# INFO:root:Will fill the histograms with the remaining 736 events
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 2822 events
# INFO:root:Applying SR1 selection on 2822 events
# INFO:root:Will fill the histograms with the remaining 292 events
# INFO:root:Applying TopCR selection on 2822 events
# INFO:root:Will fill the histograms with the remaining 27 events
# INFO:root:Applying WJetsCR selection on 2822 events
# INFO:root:Will fill the histograms with the remaining 213 events
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 3479 events
# INFO:root:Applying SR1 selection on 3479 events
# INFO:root:Will fill the histograms with the remaining 396 events
# INFO:root:Applying TopCR selection on 3479 events
# INFO:root:Will fill the histograms with the remaining 31 events
# INFO:root:Applying WJetsCR selection on 3479 events
# INFO:root:Will fill the histograms with the remaining 332 events
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 9675 events
# INFO:root:Applying SR1 selection on 9674 events
# INFO:root:Will fill the histograms with the remaining 1198 events
# INFO:root:Applying TopCR selection on 9674 events
# INFO:root:Will fill the histograms with the remaining 122 events
# INFO:root:Applying WJetsCR selection on 9674 events
# INFO:root:Will fill the histograms with the remaining 808 events
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 3599 events
# INFO:root:Applying SR1 selection on 3597 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 3597 events
# INFO:root:Will fill the histograms with the remaining 179 events
# INFO:root:Applying WJetsCR selection on 3597 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 3301 events
# INFO:root:Applying SR1 selection on 3300 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying TopCR selection on 3300 events
# INFO:root:Will fill the histograms with the remaining 226 events
# INFO:root:Applying WJetsCR selection on 3300 events
# INFO:root:Will fill the histograms with the remaining 13 events
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 8713 events
# INFO:root:Applying SR1 selection on 8711 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Applying TopCR selection on 8711 events
# INFO:root:Will fill the histograms with the remaining 595 events
# INFO:root:Applying WJetsCR selection on 8711 events
# INFO:root:Will fill the histograms with the remaining 19 events
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 2555 events
# INFO:root:Applying SR1 selection on 2554 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Applying TopCR selection on 2554 events
# INFO:root:Will fill the histograms with the remaining 321 events
# INFO:root:Applying WJetsCR selection on 2554 events
# INFO:root:Will fill the histograms with the remaining 15 events
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 2420 events
# INFO:root:Applying SR1 selection on 2420 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Applying TopCR selection on 2420 events
# INFO:root:Will fill the histograms with the remaining 308 events
# INFO:root:Applying WJetsCR selection on 2420 events
# INFO:root:Will fill the histograms with the remaining 9 events
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 105221 events
# INFO:root:Applying SR1 selection on 105203 events
# INFO:root:Will fill the histograms with the remaining 157 events
# INFO:root:Applying TopCR selection on 105203 events
# INFO:root:Will fill the histograms with the remaining 9170 events
# INFO:root:Applying WJetsCR selection on 105203 events
# INFO:root:Will fill the histograms with the remaining 284 events
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 5584 events
# INFO:root:Applying SR1 selection on 5583 events
# INFO:root:Will fill the histograms with the remaining 15 events
# INFO:root:Applying TopCR selection on 5583 events
# INFO:root:Will fill the histograms with the remaining 424 events
# INFO:root:Applying WJetsCR selection on 5583 events
# INFO:root:Will fill the histograms with the remaining 13 events
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 597535 events
# INFO:root:Applying SR1 selection on 597494 events
# INFO:root:Will fill the histograms with the remaining 815 events
# INFO:root:Applying TopCR selection on 597494 events
# INFO:root:Will fill the histograms with the remaining 53507 events
# INFO:root:Applying WJetsCR selection on 597494 events
# INFO:root:Will fill the histograms with the remaining 2571 events
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying fj_mass selection on 354 events
# INFO:root:Applying SR1 selection on 354 events
# INFO:root:Will fill the histograms with the remaining 14 events
# INFO:root:Applying TopCR selection on 354 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying WJetsCR selection on 354 events
# INFO:root:Will fill the histograms with the remaining 48 events
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 7 events
# INFO:root:Applying SR1 selection on 7 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 7 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying WJetsCR selection on 7 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 63601 events
# INFO:root:Applying SR1 selection on 63595 events
# INFO:root:Will fill the histograms with the remaining 80 events
# INFO:root:Applying TopCR selection on 63595 events
# INFO:root:Will fill the histograms with the remaining 2103 events
# INFO:root:Applying WJetsCR selection on 63595 events
# INFO:root:Will fill the histograms with the remaining 925 events
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 4061 events
# INFO:root:Applying SR1 selection on 4061 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying TopCR selection on 4061 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Applying WJetsCR selection on 4061 events
# INFO:root:Will fill the histograms with the remaining 8 events
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 27939 events
# INFO:root:Applying SR1 selection on 27936 events
# INFO:root:Will fill the histograms with the remaining 12 events
# INFO:root:Applying TopCR selection on 27936 events
# INFO:root:Will fill the histograms with the remaining 1514 events
# INFO:root:Applying WJetsCR selection on 27936 events
# INFO:root:Will fill the histograms with the remaining 179 events
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 11539 events
# INFO:root:Applying SR1 selection on 11538 events
# INFO:root:Will fill the histograms with the remaining 24 events
# INFO:root:Applying TopCR selection on 11538 events
# INFO:root:Will fill the histograms with the remaining 50 events
# INFO:root:Applying WJetsCR selection on 11538 events
# INFO:root:Will fill the histograms with the remaining 149 events
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 30783 events
# INFO:root:Applying SR1 selection on 30777 events
# INFO:root:Will fill the histograms with the remaining 60 events
# INFO:root:Applying TopCR selection on 30777 events
# INFO:root:Will fill the histograms with the remaining 380 events
# INFO:root:Applying WJetsCR selection on 30777 events
# INFO:root:Will fill the histograms with the remaining 603 events
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 41856 events
# INFO:root:Applying SR1 selection on 41852 events
# INFO:root:Will fill the histograms with the remaining 87 events
# INFO:root:Applying TopCR selection on 41852 events
# INFO:root:Will fill the histograms with the remaining 868 events
# INFO:root:Applying WJetsCR selection on 41852 events
# INFO:root:Will fill the histograms with the remaining 820 events
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 15 events
# INFO:root:Applying SR1 selection on 15 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 15 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying WJetsCR selection on 15 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 198 events
# INFO:root:Applying SR1 selection on 198 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 198 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying WJetsCR selection on 198 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 440 events
# INFO:root:Applying SR1 selection on 440 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Applying TopCR selection on 440 events
# INFO:root:Will fill the histograms with the remaining 13 events
# INFO:root:Applying WJetsCR selection on 440 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 1222 events
# INFO:root:Applying SR1 selection on 1222 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Applying TopCR selection on 1222 events
# INFO:root:Will fill the histograms with the remaining 9 events
# INFO:root:Applying WJetsCR selection on 1222 events
# INFO:root:Will fill the histograms with the remaining 29 events
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 513 events
# INFO:root:Applying SR1 selection on 513 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 513 events
# INFO:root:Will fill the histograms with the remaining 8 events
# INFO:root:Applying WJetsCR selection on 513 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 61 events
# INFO:root:Applying SR1 selection on 61 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 61 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying WJetsCR selection on 61 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 357 events
# INFO:root:Applying SR1 selection on 357 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 357 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Applying WJetsCR selection on 357 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 718 events
# INFO:root:Applying SR1 selection on 718 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying TopCR selection on 718 events
# INFO:root:Will fill the histograms with the remaining 14 events
# INFO:root:Applying WJetsCR selection on 718 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 50 events
# INFO:root:Applying SR1 selection on 50 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 50 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying WJetsCR selection on 50 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying fj_mass selection on 26152 events
# INFO:root:Applying SR1 selection on 26148 events
# INFO:root:Will fill the histograms with the remaining 388 events
# INFO:root:Applying TopCR selection on 26148 events
# INFO:root:Will fill the histograms with the remaining 4473 events
# INFO:root:Applying WJetsCR selection on 26148 events
# INFO:root:Will fill the histograms with the remaining 777 events
# INFO:root:Finding SingleElectron_Run2016F samples and should combine them under Data
# INFO:root:Finding SingleElectron_Run2016G samples and should combine them under Data
# INFO:root:Finding SingleElectron_Run2016H samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016F samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 1087 events
# INFO:root:Applying SR1 selection on 1087 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying TopCR selection on 1087 events
# INFO:root:Will fill the histograms with the remaining 79 events
# INFO:root:Applying WJetsCR selection on 1087 events
# INFO:root:Will fill the histograms with the remaining 10 events
# INFO:root:Finding SingleMuon_Run2016G samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 19696 events
# INFO:root:Applying SR1 selection on 19696 events
# INFO:root:Will fill the histograms with the remaining 39 events
# INFO:root:Applying TopCR selection on 19696 events
# INFO:root:Will fill the histograms with the remaining 1357 events
# INFO:root:Applying WJetsCR selection on 19696 events
# INFO:root:Will fill the histograms with the remaining 165 events
# INFO:root:Finding SingleMuon_Run2016H samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 22543 events
# INFO:root:Applying SR1 selection on 22543 events
# INFO:root:Will fill the histograms with the remaining 55 events
# INFO:root:Applying TopCR selection on 22543 events
# INFO:root:Will fill the histograms with the remaining 1562 events
# INFO:root:Applying WJetsCR selection on 22543 events
# INFO:root:Will fill the histograms with the remaining 203 events
# INFO:root:Processing year 2016 and ele channel
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 334 events
# INFO:root:Applying SR1 selection on 334 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 334 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying WJetsCR selection on 334 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 15931 events
# INFO:root:Applying SR1 selection on 15926 events
# INFO:root:Will fill the histograms with the remaining 13 events
# INFO:root:Applying TopCR selection on 15926 events
# INFO:root:Will fill the histograms with the remaining 93 events
# INFO:root:Applying WJetsCR selection on 15926 events
# INFO:root:Will fill the histograms with the remaining 64 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 161308 events
# INFO:root:Applying SR1 selection on 161268 events
# INFO:root:Will fill the histograms with the remaining 20 events
# INFO:root:Applying TopCR selection on 161268 events
# INFO:root:Will fill the histograms with the remaining 1354 events
# INFO:root:Applying WJetsCR selection on 161268 events
# INFO:root:Will fill the histograms with the remaining 287 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 55541 events
# INFO:root:Applying SR1 selection on 55531 events
# INFO:root:Will fill the histograms with the remaining 8 events
# INFO:root:Applying TopCR selection on 55531 events
# INFO:root:Will fill the histograms with the remaining 868 events
# INFO:root:Applying WJetsCR selection on 55531 events
# INFO:root:Will fill the histograms with the remaining 89 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 1275 events
# INFO:root:Applying SR1 selection on 1275 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 1275 events
# INFO:root:Will fill the histograms with the remaining 12 events
# INFO:root:Applying WJetsCR selection on 1275 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 64793 events
# INFO:root:Applying SR1 selection on 64790 events
# INFO:root:Will fill the histograms with the remaining 10 events
# INFO:root:Applying TopCR selection on 64790 events
# INFO:root:Will fill the histograms with the remaining 1500 events
# INFO:root:Applying WJetsCR selection on 64790 events
# INFO:root:Will fill the histograms with the remaining 137 events
# INFO:root:Finding EWKWminus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 646 events
# INFO:root:Applying SR1 selection on 646 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying TopCR selection on 646 events
# INFO:root:Will fill the histograms with the remaining 35 events
# INFO:root:Applying WJetsCR selection on 646 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding EWKWminus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 37 events
# INFO:root:Applying SR1 selection on 37 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 37 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Applying WJetsCR selection on 37 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding EWKWplus_WToLNu samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 569 events
# INFO:root:Applying SR1 selection on 569 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 569 events
# INFO:root:Will fill the histograms with the remaining 40 events
# INFO:root:Applying WJetsCR selection on 569 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Finding EWKWplus_WToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 56 events
# INFO:root:Applying SR1 selection on 56 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 56 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying WJetsCR selection on 56 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding EWKZ_ZToLL samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 270 events
# INFO:root:Applying SR1 selection on 270 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 270 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Applying WJetsCR selection on 270 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding EWKZ_ZToNuNu samples and should combine them under EWKvjets
# INFO:root:Finding EWKZ_ZToQQ samples and should combine them under EWKvjets
# INFO:root:Applying fj_mass selection on 38 events
# INFO:root:Applying SR1 selection on 38 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 38 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Applying WJetsCR selection on 38 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying fj_mass selection on 1310 events
# INFO:root:Applying SR1 selection on 1310 events
# INFO:root:Will fill the histograms with the remaining 16 events
# INFO:root:Applying TopCR selection on 1310 events
# INFO:root:Will fill the histograms with the remaining 9 events
# INFO:root:Applying WJetsCR selection on 1310 events
# INFO:root:Will fill the histograms with the remaining 194 events
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 5858 events
# INFO:root:Applying SR1 selection on 5858 events
# INFO:root:Will fill the histograms with the remaining 320 events
# INFO:root:Applying TopCR selection on 5858 events
# INFO:root:Will fill the histograms with the remaining 117 events
# INFO:root:Applying WJetsCR selection on 5858 events
# INFO:root:Will fill the histograms with the remaining 416 events
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 1484 events
# INFO:root:Applying SR1 selection on 1484 events
# INFO:root:Will fill the histograms with the remaining 132 events
# INFO:root:Applying TopCR selection on 1484 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Applying WJetsCR selection on 1484 events
# INFO:root:Will fill the histograms with the remaining 101 events
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 1897 events
# INFO:root:Applying SR1 selection on 1897 events
# INFO:root:Will fill the histograms with the remaining 158 events
# INFO:root:Applying TopCR selection on 1897 events
# INFO:root:Will fill the histograms with the remaining 15 events
# INFO:root:Applying WJetsCR selection on 1897 events
# INFO:root:Will fill the histograms with the remaining 135 events
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 5933 events
# INFO:root:Applying SR1 selection on 5933 events
# INFO:root:Will fill the histograms with the remaining 550 events
# INFO:root:Applying TopCR selection on 5933 events
# INFO:root:Will fill the histograms with the remaining 57 events
# INFO:root:Applying WJetsCR selection on 5933 events
# INFO:root:Will fill the histograms with the remaining 343 events
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 2059 events
# INFO:root:Applying SR1 selection on 2058 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Applying TopCR selection on 2058 events
# INFO:root:Will fill the histograms with the remaining 103 events
# INFO:root:Applying WJetsCR selection on 2058 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 1756 events
# INFO:root:Applying SR1 selection on 1755 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 1755 events
# INFO:root:Will fill the histograms with the remaining 91 events
# INFO:root:Applying WJetsCR selection on 1755 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 4561 events
# INFO:root:Applying SR1 selection on 4561 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Applying TopCR selection on 4561 events
# INFO:root:Will fill the histograms with the remaining 279 events
# INFO:root:Applying WJetsCR selection on 4561 events
# INFO:root:Will fill the histograms with the remaining 12 events
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 1667 events
# INFO:root:Applying SR1 selection on 1667 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying TopCR selection on 1667 events
# INFO:root:Will fill the histograms with the remaining 181 events
# INFO:root:Applying WJetsCR selection on 1667 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 1666 events
# INFO:root:Applying SR1 selection on 1666 events
# INFO:root:Will fill the histograms with the remaining 11 events
# INFO:root:Applying TopCR selection on 1666 events
# INFO:root:Will fill the histograms with the remaining 191 events
# INFO:root:Applying WJetsCR selection on 1666 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 64514 events
# INFO:root:Applying SR1 selection on 64508 events
# INFO:root:Will fill the histograms with the remaining 102 events
# INFO:root:Applying TopCR selection on 64508 events
# INFO:root:Will fill the histograms with the remaining 5597 events
# INFO:root:Applying WJetsCR selection on 64508 events
# INFO:root:Will fill the histograms with the remaining 163 events
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 1103 events
# INFO:root:Applying SR1 selection on 1103 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Applying TopCR selection on 1103 events
# INFO:root:Will fill the histograms with the remaining 111 events
# INFO:root:Applying WJetsCR selection on 1103 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 380405 events
# INFO:root:Applying SR1 selection on 380391 events
# INFO:root:Will fill the histograms with the remaining 514 events
# INFO:root:Applying TopCR selection on 380391 events
# INFO:root:Will fill the histograms with the remaining 34068 events
# INFO:root:Applying WJetsCR selection on 380391 events
# INFO:root:Will fill the histograms with the remaining 1169 events
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying fj_mass selection on 225 events
# INFO:root:Applying SR1 selection on 225 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Applying TopCR selection on 225 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying WJetsCR selection on 225 events
# INFO:root:Will fill the histograms with the remaining 31 events
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 11 events
# INFO:root:Applying SR1 selection on 11 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 11 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying WJetsCR selection on 11 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 38996 events
# INFO:root:Applying SR1 selection on 38993 events
# INFO:root:Will fill the histograms with the remaining 40 events
# INFO:root:Applying TopCR selection on 38993 events
# INFO:root:Will fill the histograms with the remaining 1305 events
# INFO:root:Applying WJetsCR selection on 38993 events
# INFO:root:Will fill the histograms with the remaining 353 events
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 3063 events
# INFO:root:Applying SR1 selection on 3062 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 3062 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying WJetsCR selection on 3062 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 16493 events
# INFO:root:Applying SR1 selection on 16491 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Applying TopCR selection on 16491 events
# INFO:root:Will fill the histograms with the remaining 947 events
# INFO:root:Applying WJetsCR selection on 16491 events
# INFO:root:Will fill the histograms with the remaining 55 events
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 7423 events
# INFO:root:Applying SR1 selection on 7422 events
# INFO:root:Will fill the histograms with the remaining 8 events
# INFO:root:Applying TopCR selection on 7422 events
# INFO:root:Will fill the histograms with the remaining 40 events
# INFO:root:Applying WJetsCR selection on 7422 events
# INFO:root:Will fill the histograms with the remaining 82 events
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 18783 events
# INFO:root:Applying SR1 selection on 18781 events
# INFO:root:Will fill the histograms with the remaining 31 events
# INFO:root:Applying TopCR selection on 18781 events
# INFO:root:Will fill the histograms with the remaining 252 events
# INFO:root:Applying WJetsCR selection on 18781 events
# INFO:root:Will fill the histograms with the remaining 299 events
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 25960 events
# INFO:root:Applying SR1 selection on 25958 events
# INFO:root:Will fill the histograms with the remaining 56 events
# INFO:root:Applying TopCR selection on 25958 events
# INFO:root:Will fill the histograms with the remaining 535 events
# INFO:root:Applying WJetsCR selection on 25958 events
# INFO:root:Will fill the histograms with the remaining 392 events
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 22 events
# INFO:root:Applying SR1 selection on 22 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 22 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying WJetsCR selection on 22 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 259 events
# INFO:root:Applying SR1 selection on 259 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying TopCR selection on 259 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Applying WJetsCR selection on 259 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 490 events
# INFO:root:Applying SR1 selection on 490 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 490 events
# INFO:root:Will fill the histograms with the remaining 17 events
# INFO:root:Applying WJetsCR selection on 490 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 881 events
# INFO:root:Applying SR1 selection on 881 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Applying TopCR selection on 881 events
# INFO:root:Will fill the histograms with the remaining 11 events
# INFO:root:Applying WJetsCR selection on 881 events
# INFO:root:Will fill the histograms with the remaining 17 events
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 529 events
# INFO:root:Applying SR1 selection on 529 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Applying TopCR selection on 529 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Applying WJetsCR selection on 529 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 38 events
# INFO:root:Applying SR1 selection on 38 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 38 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying WJetsCR selection on 38 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 198 events
# INFO:root:Applying SR1 selection on 198 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 198 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying WJetsCR selection on 198 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 334 events
# INFO:root:Applying SR1 selection on 334 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 334 events
# INFO:root:Will fill the histograms with the remaining 13 events
# INFO:root:Applying WJetsCR selection on 334 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 89 events
# INFO:root:Applying SR1 selection on 89 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 89 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying WJetsCR selection on 89 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying fj_mass selection on 14882 events
# INFO:root:Applying SR1 selection on 14881 events
# INFO:root:Will fill the histograms with the remaining 161 events
# INFO:root:Applying TopCR selection on 14881 events
# INFO:root:Will fill the histograms with the remaining 2536 events
# INFO:root:Applying WJetsCR selection on 14881 events
# INFO:root:Will fill the histograms with the remaining 352 events
# INFO:root:Finding SingleElectron_Run2016F samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 769 events
# INFO:root:Applying SR1 selection on 769 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Applying TopCR selection on 769 events
# INFO:root:Will fill the histograms with the remaining 44 events
# INFO:root:Applying WJetsCR selection on 769 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Finding SingleElectron_Run2016G samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 14380 events
# INFO:root:Applying SR1 selection on 14380 events
# INFO:root:Will fill the histograms with the remaining 24 events
# INFO:root:Applying TopCR selection on 14380 events
# INFO:root:Will fill the histograms with the remaining 916 events
# INFO:root:Applying WJetsCR selection on 14380 events
# INFO:root:Will fill the histograms with the remaining 100 events
# INFO:root:Finding SingleElectron_Run2016H samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 15865 events
# INFO:root:Applying SR1 selection on 15865 events
# INFO:root:Will fill the histograms with the remaining 34 events
# INFO:root:Applying TopCR selection on 15865 events
# INFO:root:Will fill the histograms with the remaining 1076 events
# INFO:root:Applying WJetsCR selection on 15865 events
# INFO:root:Will fill the histograms with the remaining 94 events
# INFO:root:Finding SingleMuon_Run2016F samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016G samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2016H samples and should combine them under Data
# INFO:root:Processing year 2016APV and mu channel
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# year, factor 2016APV 1.1
# INFO:root:Applying fj_mass selection on 429 events
# INFO:root:Applying SR1 selection on 429 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 429 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Applying WJetsCR selection on 429 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 12582 events
# INFO:root:Applying SR1 selection on 12570 events
# INFO:root:Will fill the histograms with the remaining 11 events
# INFO:root:Applying TopCR selection on 12570 events
# INFO:root:Will fill the histograms with the remaining 94 events
# INFO:root:Applying WJetsCR selection on 12570 events
# INFO:root:Will fill the histograms with the remaining 87 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 62238 events
# INFO:root:Applying SR1 selection on 62199 events
# INFO:root:Will fill the histograms with the remaining 43 events
# INFO:root:Applying TopCR selection on 62199 events
# INFO:root:Will fill the histograms with the remaining 573 events
# INFO:root:Applying WJetsCR selection on 62199 events
# INFO:root:Will fill the histograms with the remaining 481 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 24951 events
# INFO:root:Applying SR1 selection on 24941 events
# INFO:root:Will fill the histograms with the remaining 20 events
# INFO:root:Applying TopCR selection on 24941 events
# INFO:root:Will fill the histograms with the remaining 428 events
# INFO:root:Applying WJetsCR selection on 24941 events
# INFO:root:Will fill the histograms with the remaining 217 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 1736 events
# INFO:root:Applying SR1 selection on 1736 events
# ...
# INFO:root:Applying WJetsCR selection on 95604 events
# INFO:root:Will fill the histograms with the remaining 1631 events
# INFO:root:Finding WJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding WJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Finding WJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 470 events
# INFO:root:Applying SR1 selection on 456 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Applying TopCR selection on 456 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying WJetsCR selection on 456 events
# INFO:root:Will fill the histograms with the remaining 8 events
# INFO:root:Finding WJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 967 events
# INFO:root:Applying SR1 selection on 947 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Applying TopCR selection on 947 events
# INFO:root:Will fill the histograms with the remaining 24 events
# INFO:root:Applying WJetsCR selection on 947 events
# INFO:root:Will fill the histograms with the remaining 14 events
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 365 events
# INFO:root:Applying SR1 selection on 362 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 362 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Applying WJetsCR selection on 362 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 578 events
# INFO:root:Applying SR1 selection on 570 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 570 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Applying WJetsCR selection on 570 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding ZJetsToQQ_HT-200to400 samples and should combine them under WZQQ
# INFO:root:Finding ZJetsToQQ_HT-400to600 samples and should combine them under WZQQ
# INFO:root:Finding ZJetsToQQ_HT-600to800 samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 344 events
# INFO:root:Applying SR1 selection on 336 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 336 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Applying WJetsCR selection on 336 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding ZJetsToQQ_HT-800toInf samples and should combine them under WZQQ
# INFO:root:Applying fj_mass selection on 599 events
# INFO:root:Applying SR1 selection on 587 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Applying TopCR selection on 587 events
# INFO:root:Will fill the histograms with the remaining 29 events
# INFO:root:Applying WJetsCR selection on 587 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 332 events
# INFO:root:Applying SR1 selection on 325 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Applying TopCR selection on 325 events
# INFO:root:Will fill the histograms with the remaining 7 events
# INFO:root:Applying WJetsCR selection on 325 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying fj_mass selection on 13472 events
# INFO:root:Applying SR1 selection on 13324 events
# INFO:root:Will fill the histograms with the remaining 129 events
# INFO:root:Applying TopCR selection on 13324 events
# INFO:root:Will fill the histograms with the remaining 2288 events
# INFO:root:Applying WJetsCR selection on 13324 events
# INFO:root:Will fill the histograms with the remaining 348 events
# INFO:root:Finding EGamma_Run2018A samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 25054 events
# INFO:root:Applying SR1 selection on 25054 events
# INFO:root:Will fill the histograms with the remaining 27 events
# INFO:root:Applying TopCR selection on 25054 events
# INFO:root:Will fill the histograms with the remaining 1741 events
# INFO:root:Applying WJetsCR selection on 25054 events
# INFO:root:Will fill the histograms with the remaining 175 events
# INFO:root:Finding EGamma_Run2018B samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 12908 events
# INFO:root:Applying SR1 selection on 12908 events
# INFO:root:Will fill the histograms with the remaining 22 events
# INFO:root:Applying TopCR selection on 12908 events
# INFO:root:Will fill the histograms with the remaining 871 events
# INFO:root:Applying WJetsCR selection on 12908 events
# INFO:root:Will fill the histograms with the remaining 108 events
# INFO:root:Finding EGamma_Run2018C samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 11730 events
# INFO:root:Applying SR1 selection on 11730 events
# INFO:root:Will fill the histograms with the remaining 18 events
# INFO:root:Applying TopCR selection on 11730 events
# INFO:root:Will fill the histograms with the remaining 808 events
# INFO:root:Applying WJetsCR selection on 11730 events
# INFO:root:Will fill the histograms with the remaining 83 events
# INFO:root:Finding EGamma_Run2018D samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 54246 events
# INFO:root:Applying SR1 selection on 54246 events
# INFO:root:Will fill the histograms with the remaining 96 events
# INFO:root:Applying TopCR selection on 54246 events
# INFO:root:Will fill the histograms with the remaining 3513 events
# INFO:root:Applying WJetsCR selection on 54246 events
# INFO:root:Will fill the histograms with the remaining 434 events
# INFO:root:Finding SingleMuon_Run2018A samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2018B samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2018C samples and should combine them under Data
# INFO:root:Finding SingleMuon_Run2018D samples and should combine them under Data
# INFO:root:Applying fj_mass selection on 73133 events
# INFO:root:Applying SR1 selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying TopCR selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying WJetsCR selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying fj_mass selection on 85711 events
# INFO:root:Applying SR1 selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying TopCR selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying WJetsCR selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying fj_mass selection on 147477 events
# INFO:root:Applying SR1 selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying TopCR selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying WJetsCR selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying fj_mass selection on 255189 events
# INFO:root:Applying SR1 selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# INFO:root:Applying TopCR selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# INFO:root:Applying WJetsCR selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# INFO:root:Applying fj_mass selection on 73133 events
# INFO:root:Applying SR1 selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying TopCR selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying WJetsCR selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying fj_mass selection on 85711 events
# variation fakes_SF_Up
# variation fakes_SF_Up
# variation fakes_SF_Up
# INFO:root:Applying SR1 selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying TopCR selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying WJetsCR selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# variation fakes_SF_Up
# variation fakes_SF_Up
# variation fakes_SF_Up
# INFO:root:Applying fj_mass selection on 147477 events
# INFO:root:Applying SR1 selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying TopCR selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying WJetsCR selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# variation fakes_SF_Up
# variation fakes_SF_Up
# variation fakes_SF_Up
# INFO:root:Applying fj_mass selection on 255189 events
# INFO:root:Applying SR1 selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# INFO:root:Applying TopCR selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# variation fakes_SF_Up
# variation fakes_SF_Up
# INFO:root:Applying WJetsCR selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# INFO:root:Applying fj_mass selection on 73133 events
# variation fakes_SF_Up
# INFO:root:Applying SR1 selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying TopCR selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying WJetsCR selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# variation fakes_SF_Down
# variation fakes_SF_Down
# variation fakes_SF_Down
# INFO:root:Applying fj_mass selection on 85711 events
# INFO:root:Applying SR1 selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying TopCR selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying WJetsCR selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# variation fakes_SF_Down
# variation fakes_SF_Down
# variation fakes_SF_Down
# INFO:root:Applying fj_mass selection on 147477 events
# INFO:root:Applying SR1 selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying TopCR selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying WJetsCR selection on 147477 events
# variation fakes_SF_Down
# variation fakes_SF_Down
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying fj_mass selection on 255189 events
# variation fakes_SF_Down
# INFO:root:Applying SR1 selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# INFO:root:Applying TopCR selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# variation fakes_SF_Down
# variation fakes_SF_Down
# INFO:root:Applying WJetsCR selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# INFO:root:Applying fj_mass selection on 73133 events
# variation fakes_SF_Down
# INFO:root:Applying SR1 selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying TopCR selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying WJetsCR selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying fj_mass selection on 85711 events
# variation fakes_DR_Up
# variation fakes_DR_Up
# variation fakes_DR_Up
# INFO:root:Applying SR1 selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying TopCR selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying WJetsCR selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# variation fakes_DR_Up
# variation fakes_DR_Up
# variation fakes_DR_Up
# INFO:root:Applying fj_mass selection on 147477 events
# INFO:root:Applying SR1 selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying TopCR selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying WJetsCR selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# variation fakes_DR_Up
# variation fakes_DR_Up
# variation fakes_DR_Up
# INFO:root:Applying fj_mass selection on 255189 events
# INFO:root:Applying SR1 selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# INFO:root:Applying TopCR selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# variation fakes_DR_Up
# variation fakes_DR_Up
# INFO:root:Applying WJetsCR selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# INFO:root:Applying fj_mass selection on 73133 events
# variation fakes_DR_Up
# INFO:root:Applying SR1 selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying TopCR selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying WJetsCR selection on 73133 events
# INFO:root:Will fill the histograms with the remaining 73133 events
# INFO:root:Applying fj_mass selection on 85711 events
# variation fakes_DR_Down
# variation fakes_DR_Down
# variation fakes_DR_Down
# INFO:root:Applying SR1 selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying TopCR selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# INFO:root:Applying WJetsCR selection on 85711 events
# INFO:root:Will fill the histograms with the remaining 85711 events
# variation fakes_DR_Down
# variation fakes_DR_Down
# variation fakes_DR_Down
# INFO:root:Applying fj_mass selection on 147477 events
# INFO:root:Applying SR1 selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying TopCR selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# INFO:root:Applying WJetsCR selection on 147477 events
# INFO:root:Will fill the histograms with the remaining 147477 events
# variation fakes_DR_Down
# variation fakes_DR_Down
# variation fakes_DR_Down
# INFO:root:Applying fj_mass selection on 255189 events
# INFO:root:Applying SR1 selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# INFO:root:Applying TopCR selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# variation fakes_DR_Down
# variation fakes_DR_Down
# INFO:root:Applying WJetsCR selection on 255189 events
# INFO:root:Will fill the histograms with the remaining 255189 events
# variation fakes_DR_Down
# got neg bins
# SR1, Fake, has 3 bins with negative yield.. will set them to 0
# got neg bins
# TopCR, Fake, has 3 bins with negative yield.. will set them to 0
# got neg bins
# WJetsCR, Fake, has 3 bins with negative yield.. will set them to 0
